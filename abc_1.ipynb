# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
from simulator import simulate

# %%
# Load observed data from the 'data' directory
obs_infected = pd.read_csv('data/infected_timeseries.csv')
obs_rewiring = pd.read_csv('data/rewiring_timeseries.csv')
obs_degrees = pd.read_csv('data/final_degree_histograms.csv')

# %%
peaks_per_rep = obs_infected.groupby('replicate_id')['infected_fraction'].max()
rewires_per_rep = obs_rewiring.groupby('replicate_id')['rewire_count'].sum()

N_agents = 200
obs_degrees['deg_x_count'] = obs_degrees['degree'] * obs_degrees['count']
obs_degrees['deg2_x_count'] = (obs_degrees['degree']**2) * obs_degrees['count']
mean_deg_per_rep = obs_degrees.groupby('replicate_id')['deg_x_count'].sum() / N_agents
var_deg_per_rep = obs_degrees.groupby('replicate_id')['deg2_x_count'].sum() / N_agents - mean_deg_per_rep**2

target_peak = peaks_per_rep.mean()
std_peak = peaks_per_rep.std()

target_rewires = rewires_per_rep.mean()
std_rewires = rewires_per_rep.std()

target_var_deg = var_deg_per_rep.mean()
std_var_deg = var_deg_per_rep.std()

print("=== Targets & Normalization Weights (Std) ===")
print(f"Peak Infected : Mean = {target_peak:.3f}, Std = {std_peak:.3f}")
print(f"Total Rewires : Mean = {target_rewires:.1f}, Std = {std_rewires:.1f}")
# print(f"Degree Variance: Mean = {target_var_deg:.2f}, Std = {std_var_deg:.2f}")
# Out:
# === Targets & Normalization Weights (Std) ===
# Peak Infected : Mean = 0.657, Std = 0.043
# Total Rewires : Mean = 545.1, Std = 38.6

# %%
N_particles = 100_000
tolerance = 2.0

accepted_params = []
rng = np.random.default_rng(100)
degrees_arr = np.arange(31)

print("Starting ABC with Normalized Euclidean Distance...")

for i in range(N_particles):
    beta = rng.uniform(0.05, 0.50)
    gamma = rng.uniform(0.02, 0.20)
    rho = rng.uniform(0.0, 0.8)
    
    sim_infected, sim_rewires, sim_degrees = simulate(beta=beta, gamma=gamma, rho=rho, rng=rng)
    
    sim_peak = np.max(sim_infected)
    sim_rewires_tot = np.sum(sim_rewires)
    # sim_mean_deg = np.sum(degrees_arr * sim_degrees) / N_agents
    # sim_var_deg = np.sum((degrees_arr**2) * sim_degrees) / N_agents - sim_mean_deg**2
    
    norm_diff_peak = (sim_peak - target_peak) / std_peak
    norm_diff_rewires = (sim_rewires_tot - target_rewires) / std_rewires
    # norm_diff_deg = (sim_var_deg - target_var_deg) / std_var_deg
    
    distance = np.sqrt(norm_diff_peak**2 + norm_diff_rewires**2)
    
    if distance < tolerance:
        accepted_params.append({'beta': beta, 'gamma': gamma, 'rho': rho})
        
    if (i + 1) % 1000 == 0:
        print(f"Processed {i + 1}/{N_particles}... Current accepted: {len(accepted_params)}")
# Out:
# Starting ABC with Normalized Euclidean Distance...
# Processed 1000/100000... Current accepted: 28
# Processed 2000/100000... Current accepted: 64
# Processed 3000/100000... Current accepted: 98
# Processed 4000/100000... Current accepted: 124
# Processed 5000/100000... Current accepted: 158
# Processed 6000/100000... Current accepted: 196
# Processed 7000/100000... Current accepted: 230
# Processed 8000/100000... Current accepted: 263
# Processed 9000/100000... Current accepted: 297
# Processed 10000/100000... Current accepted: 325
# Processed 11000/100000... Current accepted: 361
# Processed 12000/100000... Current accepted: 388
# Processed 13000/100000... Current accepted: 423
# Processed 14000/100000... Current accepted: 460
# Processed 15000/100000... Current accepted: 502
# Processed 16000/100000... Current accepted: 536
# Processed 17000/100000... Current accepted: 570
# Processed 18000/100000... Current accepted: 601
# Processed 19000/100000... Current accepted: 637
# Processed 20000/100000... Current accepted: 672
# Processed 21000/100000... Current accepted: 704
# Processed 22000/100000... Current accepted: 741
# Processed 23000/100000... Current accepted: 765
# Processed 24000/100000... Current accepted: 791
# Processed 25000/100000... Current accepted: 818
# Processed 26000/100000... Current accepted: 863
# Processed 27000/100000... Current accepted: 891
# Processed 28000/100000... Current accepted: 931
# Processed 29000/100000... Current accepted: 960
# Processed 30000/100000... Current accepted: 989
# Processed 31000/100000... Current accepted: 1027
# Processed 32000/100000... Current accepted: 1061
# Processed 33000/100000... Current accepted: 1097
# Processed 34000/100000... Current accepted: 1113
# Processed 35000/100000... Current accepted: 1147
# Processed 36000/100000... Current accepted: 1178
# Processed 37000/100000... Current accepted: 1205
# Processed 38000/100000... Current accepted: 1237
# Processed 39000/100000... Current accepted: 1269
# Processed 40000/100000... Current accepted: 1295
# Processed 41000/100000... Current accepted: 1338
# Processed 42000/100000... Current accepted: 1363
# Processed 43000/100000... Current accepted: 1386
# Processed 44000/100000... Current accepted: 1414
# Processed 45000/100000... Current accepted: 1437
# Processed 46000/100000... Current accepted: 1472
# Processed 47000/100000... Current accepted: 1502
# Processed 48000/100000... Current accepted: 1538
# Processed 49000/100000... Current accepted: 1568
# Processed 50000/100000... Current accepted: 1602
# Processed 51000/100000... Current accepted: 1649
# Processed 52000/100000... Current accepted: 1688
# Processed 53000/100000... Current accepted: 1718
# Processed 54000/100000... Current accepted: 1752
# Processed 55000/100000... Current accepted: 1790
# Processed 56000/100000... Current accepted: 1826
# Processed 57000/100000... Current accepted: 1857
# Processed 58000/100000... Current accepted: 1892
# Processed 59000/100000... Current accepted: 1924
# Processed 60000/100000... Current accepted: 1955
# Processed 61000/100000... Current accepted: 1991
# Processed 62000/100000... Current accepted: 2024
# Processed 63000/100000... Current accepted: 2051
# Processed 64000/100000... Current accepted: 2071
# Processed 65000/100000... Current accepted: 2106
# Processed 66000/100000... Current accepted: 2143
# Processed 67000/100000... Current accepted: 2174
# Processed 68000/100000... Current accepted: 2214
# Processed 69000/100000... Current accepted: 2262
# Processed 70000/100000... Current accepted: 2295
# Processed 71000/100000... Current accepted: 2333
# Processed 72000/100000... Current accepted: 2363
# Processed 73000/100000... Current accepted: 2389
# Processed 74000/100000... Current accepted: 2423
# Processed 75000/100000... Current accepted: 2467
# Processed 76000/100000... Current accepted: 2498
# Processed 77000/100000... Current accepted: 2530
# Processed 78000/100000... Current accepted: 2566
# Processed 79000/100000... Current accepted: 2601
# Processed 80000/100000... Current accepted: 2637
# Processed 81000/100000... Current accepted: 2673
# Processed 82000/100000... Current accepted: 2720
# Processed 83000/100000... Current accepted: 2756
# Processed 84000/100000... Current accepted: 2784
# Processed 85000/100000... Current accepted: 2816
# Processed 86000/100000... Current accepted: 2848
# Processed 87000/100000... Current accepted: 2879
# Processed 88000/100000... Current accepted: 2917
# Processed 89000/100000... Current accepted: 2956
# Processed 90000/100000... Current accepted: 2983
# Processed 91000/100000... Current accepted: 3025
# Processed 92000/100000... Current accepted: 3053
# Processed 93000/100000... Current accepted: 3084
# Processed 94000/100000... Current accepted: 3117
# Processed 95000/100000... Current accepted: 3162
# Processed 96000/100000... Current accepted: 3198
# Processed 97000/100000... Current accepted: 3230
# Processed 98000/100000... Current accepted: 3262
# Processed 99000/100000... Current accepted: 3294
# Processed 100000/100000... Current accepted: 3316

# %%
df_posterior = pd.DataFrame(accepted_params)
print(f"\nTotal accepted particles: {len(df_posterior)}")

bins = 25

if len(df_posterior) > 0:
    display(df_posterior.head())
    
    # ---------------------------------------------------------
    # 1. Marginal Histograms 
    # ---------------------------------------------------------
    fig, axes = plt.subplots(1, 3, figsize=(15, 4))
    
    df_posterior['beta'].hist(ax=axes[0], bins=15, color='skyblue', edgecolor='black')
    axes[0].set_title('Posterior: Beta (Infection)')
    
    df_posterior['gamma'].hist(ax=axes[1], bins=15, color='lightgreen', edgecolor='black')
    axes[1].set_title('Posterior: Gamma (Recovery)')
    
    df_posterior['rho'].hist(ax=axes[2], bins=15, color='salmon', edgecolor='black')
    axes[2].set_title('Posterior: Rho (Rewiring)')
    
    plt.tight_layout()
    
    hist_path = 'plots/posterior_histograms_s2.pdf'
    plt.savefig(hist_path, format='pdf', bbox_inches='tight')
    print(f"Saved histograms to: {hist_path}")
    
    plt.show()
    
    # ---------------------------------------------------------
    # 2. Pairwise plots
    # ---------------------------------------------------------
    print("Generating Pairwise Plots...")
    g = sns.pairplot(df_posterior, kind='kde', corner=True, 
                    plot_kws={'fill': True, 'cmap': 'Blues'}) 
    
    pairplot_path = 'plots/posterior_pairplot_s2.pdf'
    g.savefig(pairplot_path, format='pdf', bbox_inches='tight')
    print(f"Saved pairplot to: {pairplot_path}")
    
    plt.show()
    
else:
    print("No particles accepted. Try increasing 'tolerance'.")
# Out:
# Total accepted particles: 3316
#        beta     gamma       rho
# 0  0.158970  0.060353  0.317566
# 1  0.238348  0.117345  0.335078
# 2  0.455428  0.107675  0.584223
# 3  0.401077  0.157226  0.544669
# 4  0.352283  0.101535  0.530435
# Saved histograms to: plots/posterior_histograms_s2.pdf
# Generating Pairwise Plots...
# Saved pairplot to: plots/posterior_pairplot_s2.pdf
